# %% [markdown]
# <a href="https://colab.research.google.com/github/LiamGabeCS67/cs1-python-7Pearl-Gabe/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [int(input("Enter a number:")), int(input("Enter a second number")), int(input("Enter a third number"))]


largest_number = max(numbers)
print("The largest number is",largest_number)
# Out:
# Enter a number:4
# Enter a second number5
# Enter a third number7
# The largest number is 7
